# %%
import numpy as np

# %%
np.random.seed()

X = np.random.rand(5, 1) * 100  
print(X)

Y = 3.5 * X + np.random.randn(5, 1) * 20 
print(Y)
# Out:
# [[ 9.61586592]
#  [66.12781059]
#  [46.80088127]
#  [20.4068684 ]
#  [55.52643983]]
# [[ 40.44072263]
#  [233.16085749]
#  [188.08941242]
#  [ 84.41467138]
#  [192.90264813]]
