# %%
print("hello world ")
# Out:
# hello world

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df = pd.DataFrame(data)
df.loc[2]
df.loc[1]
# Out:
# Name     Aisha
# Age         13
# Marks       92
# Name: 1, dtype: object

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df = pd.DataFrame(data)
df.loc[0]
# Out:
# Name     Rahul
# Age         14
# Marks       88
# Name: 0, dtype: object

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df = pd.DataFrame(data)
df.loc[[0,1]]
# Out:
#     Name  Age  Marks
# 0  Rahul   14     88
# 1  Aisha   13     92

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

# df = pd.DataFrame(data)
df.to_string()
# Out:
# '    Name  Age  Marks\n0  Rahul   14     88\n1  Aisha   13     92\n2  Kabir   15     79'

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df.head()
# Out:
#     Name  Age  Marks
# 0  Rahul   14     88
# 1  Aisha   13     92
# 2  Kabir   15     79

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df.tail()
# Out:
#     Name  Age  Marks
# 0  Rahul   14     88
# 1  Aisha   13     92
# 2  Kabir   15     79

# %%
df=pd.read_csv(r"C:\Users\win10\Desktop\Download\daily_data.csv")
df
# Out:
#           STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0     72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 1     72518014735  2015-01-02T23:59:00       SOD         6         PRECIP
# 2     72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
# 3     72518014735  2015-01-04T23:59:00       SOD         6         PRECIP
# 4     72518014735  2015-01-05T23:59:00       SOD         6         PRECIP
# ...           ...                  ...         ...     ...            ...
# 2663  72518014735  2022-05-27T23:59:00       SOD         6         PRECIP
# 2664  72518014735  2022-05-28T23:59:00       SOD         6         PRECIP
# 2665  72518014735  2022-05-29T23:59:00       SOD         6         PRECIP
# 2666  72518014735  2022-05-30T23:59:00       SOD         6         PRECIP
# 2667  72518014735  2022-05-31T23:59:00       SOD         6         PRECIP
#
#       BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# ...

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aisha", "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}

df.info
# Out:
# <bound method DataFrame.info of           STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0     72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 1     72518014735  2015-01-02T23:59:00       SOD         6         PRECIP
# 2     72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
# 3     72518014735  2015-01-04T23:59:00       SOD         6         PRECIP
# 4     72518014735  2015-01-05T23:59:00       SOD         6         PRECIP
# ...           ...                  ...         ...     ...            ...
# 2663  72518014735  2022-05-27T23:59:00       SOD         6         PRECIP
# 2664  72518014735  2022-05-28T23:59:00       SOD         6         PRECIP
# 2665  72518014735  2022-05-29T23:59:00       SOD         6         PRECIP
# 2666  72518014735  2022-05-30T23:59:00       SOD         6         PRECIP
# 2667  72518014735  2022-05-31T23:59:00       SOD         6         PRECIP
#
# ...

# %%
import pandas as pd
import numpy as np
data = {
    "Name": ["Rahul", np.nan, "Kabir"],
    "Age": [14, 13, 15],
    "Marks": [88, 92, 79]
}
data = pd.DataFrame(data)
new_df=data.dropna()
print(data)
print(new_df)

# data.dropna(inplace=True)
# Out:
#     Name  Age  Marks
# 0  Rahul   14     88
# 1    NaN   13     92
# 2  Kabir   15     79
#     Name  Age  Marks
# 0  Rahul   14     88
# 2  Kabir   15     79

# %%
df=pd.read_json("employee_data.json")
df
# Out:
#                                             employee
# 0  {'id': 'E00001', 'name': 'Jodi Reyes', 'positi...
# 1  {'id': 'E00002', 'name': 'Kimberly Perez', 'po...
# 2  {'id': 'E00003', 'name': 'William Brown', 'pos...
# 3  {'id': 'E00004', 'name': 'Maureen Tate', 'posi...
# 4  {'id': 'E00005', 'name': 'Ashley Mitchell', 'p...
# 5  {'id': 'E00006', 'name': 'Adam Smith', 'positi...

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {
    "Name": ["Rizwan", "Aman", "Neha"],
    "Marks": [85, 90, 92],
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Marks
# 0  Rizwan     85
# 1    Aman     90
# 2    Neha     92

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\win10\Downloads\science_questions.csv")

# %%
df
# Out:
#     Question_No                                      Question_Text  \
# 0             1  Select the group in which all organisms have t...
# 1             2  Products formed after breakdown of glucose in ...
# 2             3  Correct combination of function and part of br...
# 3             4  Blood glucose level high due to inadequate sec...
# 4             5  Cross between black furred and white furred ra...
# 5             6               Correct statements related to ozone.
# 6             7  Human activity increasing non‑biodegradable su...
# 7             8  Assertion: Tallness of pea plant controlled by...
# 8             9  Assertion: Vulture has least pesticides; Reaso...
# 9            10     Plants do not have excretory products—comment.
# 10           11  Heart chambers in fishes & humans / water tran...
# 11           12       Create two food chains from given organisms.
# 12           13  Draw and explain nerve cell impulse transmission.
# ...
